# %% [markdown]
# # Remarks
# * The names of the tests and development set are inverted, i.e., we named the development set as 'test_df'.

# %% [markdown]
# # Install packages and Imports

# %%
# !pip install sklearn-crfsuite
# Out:
# Requirement already satisfied: sklearn-crfsuite in c:\users\martin\appdata\local\programs\python\python38\lib\site-packages (0.3.6)
# Requirement already satisfied: six in c:\users\martin\appdata\local\programs\python\python38\lib\site-packages (from sklearn-crfsuite) (1.16.0)
# Requirement already satisfied: tqdm>=2.0 in c:\users\martin\appdata\local\programs\python\python38\lib\site-packages (from sklearn-crfsuite) (4.62.3)
# Requirement already satisfied: tabulate in c:\users\martin\appdata\local\programs\python\python38\lib\site-packages (from sklearn-crfsuite) (0.8.9)
# Requirement already satisfied: python-crfsuite>=0.8.3 in c:\users\martin\appdata\local\programs\python\python38\lib\site-packages (from sklearn-crfsuite) (0.9.9)
# Requirement already satisfied: colorama in c:\users\martin\appdata\local\programs\python\python38\lib\site-packages (from tqdm>=2.0->sklearn-crfsuite) (0.4.4)
# WARNING: You are using pip version 21.1.1; however, version 23.0.1 is available.
# You should consider upgrading via the 'c:\users\martin\appdata\local\programs\python\python38\python.exe -m pip install --upgrade pip' command.
# ERROR: Could not find a version that satisfies the requirement sklearn-grid_search (from versions: none)
# ERROR: No matching distribution found for sklearn-grid_search
# WARNING: You are using pip version 21.1.1; however, version 23.0.1 is available.
# You should consider upgrading via the 'c:\users\martin\appdata\local\programs\python\python38\python.exe -m pip install --upgrade pip' command.

# %%
pip install --user -U scikit-learn==0.23.2
# Out:
# Collecting scikit-learn==0.23.2
#   Downloading scikit_learn-0.23.2-cp38-cp38-win_amd64.whl (6.8 MB)
# Requirement already satisfied: numpy>=1.13.3 in c:\users\martin\appdata\local\programs\python\python38\lib\site-packages (from scikit-learn==0.23.2) (1.21.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\martin\appdata\local\programs\python\python38\lib\site-packages (from scikit-learn==0.23.2) (3.0.0)
# Requirement already satisfied: scipy>=0.19.1 in c:\users\martin\appdata\local\programs\python\python38\lib\site-packages (from scikit-learn==0.23.2) (1.7.3)
# Requirement already satisfied: joblib>=0.11 in c:\users\martin\appdata\local\programs\python\python38\lib\site-packages (from scikit-learn==0.23.2) (1.1.0)
# Installing collected packages: scikit-learn
# Successfully installed scikit-learn-0.23.2
# Note: you may need to restart the kernel to use updated packages.
# WARNING: You are using pip version 21.1.1; however, version 23.0.1 is available.
# You should consider upgrading via the 'c:\Users\Martin\AppData\Local\Programs\Python\Python38\python.exe -m pip install --upgrade pip' command.

# %%
import pandas as pd
import spacy
import sklearn_crfsuite
import scipy.stats

from sklearn_crfsuite import metrics
from sklearn.metrics import classification_report
from sklearn.model_selection import RandomizedSearchCV
from sklearn.metrics import make_scorer

# %% [markdown]
# # Functions and Helpers

# %%
nlp = spacy.load("en_core_web_sm")
WINDOW = 9

def build_dataframe(file_path):
    data = []
    with open(file_path, 'r') as file:
        for line in file:
            data.append(line.strip().split('\t'))
    df = pd.DataFrame(data)

    df = df.rename(columns={0: 'file', 1: 'sentence', 2: 'position', 3: 'token', 4: 'negCue'})

    #drop empty rows
    df = df.drop(df[(df.file == '')].index)

    df.insert(len(df.columns)-1, 'lemma', None)
    df.insert(len(df.columns)-1, 'postag', None)

    for i in range(1,(WINDOW+1)):
        df.insert(len(df.columns)-1, f'lemma_a{i}', None)  #lemma of token 1-position AFTER  token
        df.insert(len(df.columns)-1, f'lemma_b{i}', None)  #lemma of token 1-position BEFORE  token

        df.insert(len(df.columns)-1, f'pos_a{i}', None)    #postag of token 1-position AFTER  token
        df.insert(len(df.columns)-1, f'pos_b{i}', None)    #postag of token 1-position BEFORE  token

    df.insert(len(df.columns)-1, 'known_cue', None)        #if token was seen as a cue during training

    df = df.astype({'sentence': 'int32'})
    df = df.astype({'position': 'int32'})

    #Encode golden label
    negCue_dict = {"negCue":     {"O": '0', "B-NEG": '1', "I-NEG": '2'}}
    df = df.replace(negCue_dict)    

    return df

def feature_extraction(dataframe,known_cues=[]):

    column_names = dataframe.columns
    new_df = pd.DataFrame(columns=column_names)

    for _file in dataframe.file.unique():
        file_df = dataframe[dataframe['file']==_file]

        file_df = file_df.groupby(['sentence']).apply(applySentenceGroupBy)

        new_df = new_df.append(file_df)

    dataframe = new_df

    dataframe = set_known_cue_feature(dataframe,known_cues)

    return dataframe

def set_known_cue_feature(df,cues):
    new_df = pd.DataFrame(columns=df.columns)
    
    for i,row in df.iterrows():
        row['known_cue'] = True if row['token'] in cues else False
        new_df = new_df.append(row,ignore_index=True)

    return new_df

def set_baseline_pred_feature(df,baseline_cues):
    new_df = pd.DataFrame(columns=df.columns)
    
    for i,row in df.iterrows():
        if row['token'] in baseline_cues['b_negs']:
            row['baseline_pred'] = 1 
        elif row['token'] in baseline_cues['i_negs']:
            row['baseline_pred'] = 2
        else:
            row['baseline_pred'] = 0

        new_df = new_df.append(row,ignore_index=True)

    return new_df
            
def applySentenceGroupBy(sentence_df):
    
    tokens = []
    for i,row in sentence_df.iterrows():
        tokens.append(row['token'])
    
    #reconstruct sentence from original df
    string = ' '.join([token for token in tokens])
    
    #use spacy to tokenize and extract info from sentence
    spacy_tokenized = nlp(string)
    
    sentence_df = add_token_features(sentence_df,spacy_tokenized,offset=1)    
    
    return sentence_df    

def add_token_features(sentence_df,spacy_tokenized,offset=1):
    i=0
    # tokens = [token for token in spacy_tokenized]
    
    sentence_ = pd.DataFrame(columns=sentence_df.columns)
    for idx,row in sentence_df.iterrows():
        
        # Both tokenizarions match:
        if row['token'] == spacy_tokenized[i].text:

            row = set_lemma_and_pos(row,spacy_tokenized,i)
        else:
            
            if row['token'] == spacy_tokenized[i-offset].text:
                row = set_lemma_and_pos(row,spacy_tokenized,i-offset)
            elif row['token'] == spacy_tokenized[i+offset].text:
                row = set_lemma_and_pos(row,spacy_tokenized,i+offset)
            else:
                #try one position more
                
                if row['token'] == spacy_tokenized[i-offset+1].text:
                    row = set_lemma_and_pos(row,spacy_tokenized,i-offset+1)
                elif row['token'] == spacy_tokenized[i+offset+1].text:
                    row = set_lemma_and_pos(row,spacy_tokenized,i+offset+1)                

        sentence_ = sentence_.append(row,ignore_index=True)
        i += 1
    
    return sentence_

def set_lemma_and_pos(row,spacy_tokenized,idx):
    #Lemma
    row['lemma']          = spacy_tokenized[idx].lemma_
    row['postag']         = spacy_tokenized[idx].tag_

    for i in range (1,(WINDOW+1)):
        row[f'lemma_b{i}']       = spacy_tokenized[idx-i].lemma_ if (idx + (1-i)) > 0 else None 
        row[f'lemma_a{i}']       = spacy_tokenized[idx+i].lemma_ if (idx+i) < len(spacy_tokenized) else None

        row[f'pos_b{i}']       = spacy_tokenized[idx-i].tag_ if (idx + (1-i)) > 0 else None 
        row[f'pos_a{i}']       = spacy_tokenized[idx+i].tag_ if (idx+i) < len(spacy_tokenized) else None

    return row

def get_training_cues(train_df):
    # print(train_df.head())
    cues= train_df.loc[(train_df['negCue']=='1')| (train_df['negCue']==1)]['token'].tolist()

    cues = list(set(cues)) #remove duplicates

    return cues

def dataframe2features(dataframe,known_cues=True,window=9):
    tokens = []
    labels = []
    for sentence_id, group in dataframe.groupby(['file','sentence']): #TODO arreglar esto para cuando saque el BREAK de files
        token = []
        label = []
        for _, row in group.iterrows():
            token_dict = {'token': row['token'],
                            'file': row['file'],
                            'sentence': row['sentence'],
                            'position': row['position']
                        }
            if known_cues:
                token_dict['known_cue'] = row['known_cue']
            
            if row['lemma'] != None:
                token_dict['lemma'] = row['lemma']
            if row['postag'] != None:
                token_dict['postag'] = row['postag']
            
            for i in range(1,window+1):
                if str(row[f'lemma_a{i}']) != 'nan':
                    token_dict[f'lemma_a{i}'] = row[f'lemma_a{i}']
                if str(row[f'lemma_b{i}']) != 'nan':
                    token_dict[f'lemma_b{i}'] = row[f'lemma_b{i}']                    
                if str(row[f'pos_b{i}']) != 'nan':
                    token_dict[f'pos_b{i}'] = row[f'pos_b{i}']                                        
                if str(row[f'pos_a{i}']) != 'nan':
                    token_dict[f'pos_a{i}'] = row[f'pos_a{i}']                                                            

            # if row['negCue'] != None:
            #     token_dict['negCue'] = row['negCue']


            token.append(token_dict)
            label.append(str(row['negCue']))
        tokens.append(token)
        labels.append(label)

    return tokens,labels

def train_crf_and_predict(X_train,y_train,X_test,y_test,c1=0.1,c2=0.1,verbose=True):
    crf = sklearn_crfsuite.CRF(
        algorithm='lbfgs',
        c1=c1,
        c2=c2,
        max_iterations=100,
        all_possible_transitions=True
    )

    crf.fit(X_train, y_train)

    labels = list(crf.classes_)
    sorted_labels = sorted(labels, key=lambda name: (name[1:], name[0]))

    y_pred = crf.predict(X_test)
    y_pred_ = []

    for sentence_preds in y_pred:
        y_pred_.extend(sentence_preds)

    y_test = y_test.astype({'negCue': str})

    print(f"len(y_test)={len(y_test)}")
    print(f"len(y_pred_)={len(y_pred_)}")
    report = classification_report(y_test, y_pred_, target_names=sorted_labels,digits=4)
    if verbose: print(report)


    return crf,report

def get_sentences(df,filtered):

    sentences = filtered.sentence.unique()
    # print(sentences)
    sentences_list = []

    for sentence_id in sentences:
        tokens = []
        sentence = ""

        sentence_df = df.loc[(df['sentence']== sentence_id)]
        
        for idx, row in sentence_df.iterrows():
            
            tokens.append(row['token'])
        
        sentence = " ".join(tokens)

        sentences_list.append(sentence)
    
    for sentence in sentences_list:
        print(f"\n-{sentence}")


def get_sentences2(df,filtered):
    sentences_list = []
    
    for idx, filt_row in filtered.iterrows():
        token = filt_row['token']
        
        file_id = filt_row['file']
        sentence_id = filt_row['sentence']
        sentence_tokens = []
        # sentence = ""

        sentence_df = df.loc[(df['sentence']== sentence_id) & (df['file']== file_id)]
        
        for idx, row in sentence_df.iterrows():
            
            sentence_tokens.append(row['token'])
        
        sentence = " ".join(sentence_tokens)

        print(f"[token: {token}]")
        print(f"\t->{sentence}\n")

        # sentences_list.append(sentence)
        
    
    # for sentence in sentences_list:
    #     print(f"\n-{sentence}")

# %% [markdown]
# # Pre-Processing and Feature Engineering (TRAIN AND TEST DFs)

# %% [markdown]
# ## Preprocess & save

# %%
train_df = build_dataframe("corpus/SEM-2012-SharedTask-CD-SCO-training-simple.v2.txt")
test_df = build_dataframe("corpus/SEM-2012-SharedTask-CD-SCO-dev-simple.v2.txt")

known_cues = get_training_cues(train_df)

train_df = feature_extraction(train_df,known_cues)
test_df = feature_extraction(test_df,known_cues)

train_df.to_csv('corpus/train_df_preproc_w9.csv', sep='\t',index=False)
test_df.to_csv('corpus/test_df_preproc_w9.csv', sep='\t',index=False)

train_df = pd.read_csv('corpus/train_df_preproc_w9.csv', sep='\t')
test_df = pd.read_csv('corpus/test_df_preproc_w9.csv', sep='\t')

train_df
# Out:
#                  file  sentence  position     token     lemma postag  \
# 0      baskervilles01         0         0   Chapter   chapter     NN
# 1      baskervilles01         0         1        1.       NaN    NaN
# 2      baskervilles01         0         2       Mr.       Mr.    NNP
# 3      baskervilles01         0         3  Sherlock  Sherlock    NNP
# 4      baskervilles01         0         4    Holmes    Holmes    NNP
# ...               ...       ...       ...       ...       ...    ...
# 65446  baskervilles14       270        58    slopes     slope    NNS
# 65447  baskervilles14       270        59        of        of     IN
# 65448  baskervilles14       270        60       the       the     DT
# 65449  baskervilles14       270        61      moor      moor     NN
# 65450  baskervilles14       270        62         .         .      .
#
#        lemma_a1  lemma_b1 pos_a1 pos_b1  ... lemma_a8 lemma_b8 pos_a8 pos_b8  \
# 0             1       NaN     CD    NaN  ...      NaN      NaN    NaN    NaN
# 1           NaN       NaN    NaN    NaN  ...      NaN      NaN    NaN    NaN
# 2      Sherlock         .    NNP      .  ...      NaN      NaN    NaN    NaN
# 3        Holmes       Mr.    NNP    NNP  ...      NaN      NaN    NaN    NaN
# 4           NaN  Sherlock    NaN    NNP  ...      NaN      NaN    NaN    NaN
# ...         ...       ...    ...    ...  ...      ...      ...    ...    ...
# 65446        of    russet     IN     NN  ...      NaN  stretch    NaN    VBD
# 65447       the     slope     DT    NNS  ...      NaN     away    NaN     RB
# 65448      moor        of     NN     IN  ...      NaN    until    NaN     IN
# 65449         .       the      .     DT  ...      NaN       it    NaN    PRP
# 65450       NaN      moor    NaN     NN  ...      NaN    merge    NaN    VBD
#
#       lemma_a9 lemma_b9 pos_a9 pos_b9 known_cue negCue
# 0          NaN      NaN    NaN    NaN     False      0
# 1          NaN      NaN    NaN    NaN     False      0
# 2          NaN      NaN    NaN    NaN     False      0
# 3          NaN      NaN    NaN    NaN     False      0
# 4          NaN      NaN    NaN    NaN     False      0
# ...        ...      ...    ...    ...       ...    ...
# 65446      NaN    which    NaN    WDT     False      0
# 65447      NaN  stretch    NaN    VBD     False      0
# 65448      NaN     away    NaN     RB     False      0
# 65449      NaN    until    NaN     IN     False      0
# 65450      NaN       it    NaN    PRP     False      0
#
# [65451 rows x 44 columns]

# %% [markdown]
# ## Building Baseline

# %%
unique_tokens = sorted(test_df['token'].unique())
baseline_dict = {}

for token in unique_tokens:
    filtered = test_df.loc[(test_df['token']== token)]
    most_freq_label = filtered['negCue'].value_counts()[:1].index.tolist()[0]
    baseline_dict[token] = most_freq_label

baseline_cues = {}
b_negs = []
i_negs = []
for key,value in baseline_dict.items():
    if value == 1:
        b_negs.append(key)
    elif value == 2:
        i_negs.append(key)
    
baseline_cues['b_negs'] = b_negs
baseline_cues['i_negs'] = i_negs

test_df = set_baseline_pred_feature(test_df,baseline_cues)

test_df = test_df.astype({'baseline_pred': int})
test_df.to_csv('corpus/test_df_preproc_w9.csv', sep='\t',index=False)

# %% [markdown]
# # Read preprocessed DFs

# %%
train_df = pd.read_csv('corpus/train_df_preproc_w9.csv', sep='\t')
test_df = pd.read_csv('corpus/test_df_preproc_w9.csv', sep='\t')

test_df
# Out:
#              file  sentence  position       token       lemma postag  \
# 0      wisteria01         0         0          1.         NaN    NaN
# 1      wisteria01         0         1         The         the     DT
# 2      wisteria01         0         2    Singular    Singular    NNP
# 3      wisteria01         0         3  Experience  Experience    NNP
# 4      wisteria01         0         4          of          of     IN
# ...           ...       ...       ...         ...         ...    ...
# 13562  wisteria02       439         9    orthodox    orthodox     JJ
# 13563  wisteria02       439        10          in          in     IN
# 13564  wisteria02       439        11         his         his   PRP$
# 13565  wisteria02       439        12      ritual      ritual     NN
# 13566  wisteria02       439        13           .           .      .
#
#          lemma_a1    lemma_b1 pos_a1 pos_b1  ... lemma_b8 pos_a8 pos_b8  \
# 0             NaN         NaN    NaN    NaN  ...      NaN    NaN    NaN
# 1        Singular           .    NNP      .  ...      NaN    NaN    NaN
# 2      Experience         the    NNP     DT  ...      NaN    NaN    NaN
# 3              of    Singular     IN    NNP  ...      NaN    NaN    NaN
# 4             Mr.  Experience    NNP    NNP  ...      NaN    NaN    NaN
# ...           ...         ...    ...    ...  ...      ...    ...    ...
# 13562          in        very     IN     RB  ...       so    NaN     RB
# 13563         his    orthodox   PRP$     JJ  ...      you    NaN    PRP
# 13564      ritual          in     NN     IN  ...      see    NaN    VBP
# 13565           .         his      .   PRP$  ...      our    NaN   PRP$
# 13566         NaN      ritual    NaN     NN  ...   savage    NaN     JJ
#
#       lemma_a9 lemma_b9 pos_a9 pos_b9 known_cue negCue baseline_pred
# 0          NaN      NaN    NaN    NaN     False      0             0
# 1          NaN      NaN    NaN    NaN     False      0             0
# 2          NaN      NaN    NaN    NaN     False      0             0
# 3          NaN      NaN    NaN    NaN     False      0             0
# 4          NaN      NaN    NaN    NaN     False      0             0
# ...        ...      ...    ...    ...       ...    ...           ...
# 13562      NaN        `    NaN     ``     False      0             0
# 13563      NaN       so    NaN     RB     False      0             0
# 13564      NaN      you    NaN    PRP     False      0             0
# 13565      NaN      see    NaN    VBP     False      0             0
# 13566      NaN      our    NaN   PRP$     False      0             0
#
# [13567 rows x 45 columns]

# %% [markdown]
# # Training and Evaluation

# %%
print("#######################################################################################")
print("BASELINE PREDICTION")
    
# y_test = y_test.astype({'negCue': str})

print(classification_report(test_df['negCue'], test_df['baseline_pred'], digits=4))

print("#######################################################################################")
print("WINDOW = 9, KNOWN_CUES = TRUE")

train_df_w9_kc = train_df 
test_df_w9_kc  = test_df 

X_train_w9_kc, y_train = dataframe2features(train_df_w9_kc,window=9)
X_test_w9_kc,  y_test  = dataframe2features(test_df_w9_kc,window=9)

crf_w9_kc, report_w9_kc = train_crf_and_predict(X_train_w9_kc,y_train,X_test_w9_kc,test_df_w9_kc['negCue'])

print("#######################################################################################")
print("WINDOW = 9, KNOWN_CUES = FALSE")

train_df_w9 = train_df.drop(columns=['known_cue'])
test_df_w9  = test_df.drop(columns=['known_cue'])

X_train_w9, y_train = dataframe2features(train_df_w9,known_cues=False,window=9)
X_test_w9,  y_test  = dataframe2features(test_df_w9,known_cues=False,window=9)

crf_w9, report_w9 = train_crf_and_predict(X_train_w9,y_train,X_test_w9,test_df_w9['negCue'])


print("#######################################################################################")
print("WINDOW = 8, KNOWN_CUES = TRUE")

train_df_w8_kc = train_df 
test_df_w8_kc  = test_df 

X_train_w8_kc, y_train = dataframe2features(train_df_w8_kc,window=8)
X_test_w8_kc,  y_test  = dataframe2features(test_df_w8_kc,window=8)

crf_w8_kc, report_w8_kc = train_crf_and_predict(X_train_w8_kc,y_train,X_test_w8_kc,test_df_w8_kc['negCue'])

print("#######################################################################################")
print("WINDOW = 8, KNOWN_CUES = FALSE")

train_df_w8 = train_df.drop(columns=['known_cue'])
test_df_w8  = test_df.drop(columns=['known_cue'])

X_train_w8, y_train = dataframe2features(train_df_w8,known_cues=False,window=8)
X_test_w8,  y_test  = dataframe2features(test_df_w8,known_cues=False,window=8)

crf_w8, report_w8 = train_crf_and_predict(X_train_w8,y_train,X_test_w8,test_df_w8['negCue'])

print("#######################################################################################")
print("WINDOW = 7, KNOWN_CUES = TRUE")

train_df_w7_kc = train_df 
test_df_w7_kc  = test_df 

X_train_w7_kc, y_train = dataframe2features(train_df_w7_kc,window=7)
X_test_w7_kc,  y_test  = dataframe2features(test_df_w7_kc,window=7)

crf_w7_kc, report_w7_kc = train_crf_and_predict(X_train_w7_kc,y_train,X_test_w7_kc,test_df_w7_kc['negCue'])

print("#######################################################################################")
print("WINDOW = 7, KNOWN_CUES = FALSE")

train_df_w7 = train_df.drop(columns=['known_cue'])
test_df_w7  = test_df.drop(columns=['known_cue'])

X_train_w7, y_train = dataframe2features(train_df_w7,known_cues=False,window=7)
X_test_w7,  y_test  = dataframe2features(test_df_w7,known_cues=False,window=7)

crf_w7, report_w7 = train_crf_and_predict(X_train_w7,y_train,X_test_w7,test_df_w7['negCue'])

print("#######################################################################################")
print("WINDOW = 6, KNOWN_CUES = TRUE")

train_df_w6_kc = train_df
test_df_w6_kc  = test_df

X_train_w6_kc, y_train = dataframe2features(train_df_w6_kc,window=6)
X_test_w6_kc,  y_test  = dataframe2features(test_df_w6_kc,window=6)

crf_w6_kc, report_w6_kc = train_crf_and_predict(X_train_w6_kc,y_train,X_test_w6_kc,test_df_w6_kc['negCue'])

print("#######################################################################################")
print("WINDOW = 6, KNOWN_CUES = FALSE")

train_df_w6 = train_df.drop(columns=['known_cue'])
test_df_w6  = test_df.drop(columns=['known_cue'])

X_train_w6, y_train = dataframe2features(train_df_w6,known_cues=False,window=6)
X_test_w6,  y_test  = dataframe2features(test_df_w6,known_cues=False,window=6)

crf_w6, report_w6 = train_crf_and_predict(X_train_w6,y_train,X_test_w6,test_df_w6['negCue'])

print("#######################################################################################")
print("WINDOW = 5, KNOWN_CUES = TRUE")

train_df_w5_kc = train_df
test_df_w5_kc  = test_df

X_train_w5_kc, y_train = dataframe2features(train_df_w5_kc,window=5)
X_test_w5_kc,  y_test  = dataframe2features(test_df_w5_kc,window=5)

crf_w5_kc, report_w5_kc = train_crf_and_predict(X_train_w5_kc,y_train,X_test_w5_kc,test_df_w5_kc['negCue'])

print("#######################################################################################")
print("WINDOW = 5, KNOWN_CUES = FALSE")

train_df_w5 = train_df.drop(columns=['known_cue'])
test_df_w5  = test_df.drop(columns=['known_cue'])

X_train_w5, y_train = dataframe2features(train_df_w5,known_cues=False,window=5)
X_test_w5,  y_test  = dataframe2features(test_df_w5,known_cues=False,window=5)

crf_w5, report_w5 = train_crf_and_predict(X_train_w5,y_train,X_test_w5,test_df_w5['negCue'])

print("#######################################################################################")
print("WINDOW = 4, KNOWN_CUES = TRUE")
    
train_df_w4_kc = train_df
test_df_w4_kc  = test_df

X_train_w4_kc, y_train = dataframe2features(train_df_w4_kc,window=4)
X_test_w4_kc,  y_test  = dataframe2features(test_df_w4_kc,window=4)

crf_w4_kc, report_w4_kc = train_crf_and_predict(X_train_w4_kc,y_train,X_test_w4_kc,test_df_w4_kc['negCue'])

print("#######################################################################################")
print("WINDOW = 4, KNOWN_CUES = FALSE")

train_df_w4 = train_df.drop(columns=['known_cue'])
test_df_w4  = test_df.drop(columns=['known_cue'])

X_train_w4, y_train = dataframe2features(train_df_w4,known_cues=False,window=4)
X_test_w4,  y_test  = dataframe2features(test_df_w4,known_cues=False,window=4)

crf_w4, report_w4 = train_crf_and_predict(X_train_w4,y_train,X_test_w4,test_df_w4['negCue'])

print("#######################################################################################")
print("WINDOW = 3, KNOWN_CUES = TRUE")

train_df_w3_kc = train_df
test_df_w3_kc  = test_df

X_train_w3_kc, y_train = dataframe2features(train_df_w3_kc,window=3)
X_test_w3_kc,  y_test  = dataframe2features(test_df_w3_kc,window=3)

crf_w3_kc, report_w3_kc = train_crf_and_predict(X_train_w3_kc,y_train,X_test_w3_kc,test_df_w3_kc['negCue'])

print("#######################################################################################")
print("WINDOW = 3, KNOWN_CUES = FALSE")

train_df_w3 = train_df.drop(columns=['known_cue'])
test_df_w3  = test_df.drop(columns=['known_cue'])

X_train_w3, y_train = dataframe2features(train_df_w3,known_cues=False,window=3)
X_test_w3,  y_test  = dataframe2features(test_df_w3,known_cues=False,window=3)

crf_w3, report_w3 = train_crf_and_predict(X_train_w3,y_train,X_test_w3,test_df_w3['negCue'])

print("#######################################################################################")
print("WINDOW = 2, KNOWN_CUES = TRUE")

train_df_w2_kc = train_df
test_df_w2_kc  = test_df

X_train_w2_kc, y_train = dataframe2features(train_df_w2_kc,window=2)
X_test_w2_kc,  y_test  = dataframe2features(test_df_w2_kc,window=2)

crf_w2_kc, report_w2_kc = train_crf_and_predict(X_train_w2_kc,y_train,X_test_w2_kc,test_df_w2_kc['negCue'])

print("#######################################################################################")
print("WINDOW = 2, KNOWN_CUES = FALSE")

train_df_w2 = train_df.drop(columns=['known_cue'])
test_df_w2  = test_df.drop(columns=['known_cue'])

X_train_w2, y_train = dataframe2features(train_df_w2,known_cues=False,window=2)
X_test_w2,  y_test  = dataframe2features(test_df_w2,known_cues=False,window=2)

crf_w2, report_w2 = train_crf_and_predict(X_train_w2,y_train,X_test_w2,test_df_w2['negCue'])

print("#######################################################################################")
print("WINDOW = 1, KNOWN_CUES = TRUE")

train_df_w1_kc = train_df
test_df_w1_kc  = test_df

X_train_w1_kc, y_train = dataframe2features(train_df_w1_kc,window=1)
X_test_w1_kc,  y_test  = dataframe2features(test_df_w1_kc,window=1)

crf_w1_kc, report_w1_kc = train_crf_and_predict(X_train_w1_kc,y_train,X_test_w1_kc,test_df_w1_kc['negCue'])

print("#######################################################################################")
print("WINDOW = 1, KNOWN_CUES = FALSE")

train_df_w1 = train_df.drop(columns=['known_cue'])
test_df_w1  = test_df.drop(columns=['known_cue'])

X_train_w1, y_train = dataframe2features(train_df_w1,known_cues=False,window=1)
X_test_w1,  y_test  = dataframe2features(test_df_w1,known_cues=False,window=1)

crf_w1, report_w1 = train_crf_and_predict(X_train_w1,y_train,X_test_w1,test_df_w1['negCue'])

print("#######################################################################################")
print("WINDOW = 0, KNOWN_CUES = TRUE")

train_df_w0_kc = train_df
test_df_w0_kc  = test_df

X_train_w0_kc, y_train = dataframe2features(train_df_w0_kc,window=0)
X_test_w0_kc,  y_test  = dataframe2features(test_df_w0_kc,window=0)

crf_w0_kc, report_w0_kc = train_crf_and_predict(X_train_w0_kc,y_train,X_test_w0_kc,test_df_w0_kc['negCue'])

print("#######################################################################################")
print("WINDOW = 0, KNOWN_CUES = FALSE")

train_df_w0 = train_df.drop(columns=['known_cue'])
test_df_w0  = test_df.drop(columns=['known_cue'])

X_train_w0, y_train = dataframe2features(train_df_w0,known_cues=False,window=0)
X_test_w0,  y_test  = dataframe2features(test_df_w0,known_cues=False,window=0)

crf_w0, report_w0 = train_crf_and_predict(X_train_w0,y_train,X_test_w0,test_df_w0['negCue'])
# Out:
# #######################################################################################
# BASELINE PREDICTION
#               precision    recall  f1-score   support
#
#            0     0.9999    0.9993    0.9996     13388
#            1     0.9459    0.9943    0.9695       176
#            2     1.0000    0.3333    0.5000         3
#
#     accuracy                         0.9991     13567
#    macro avg     0.9819    0.7757    0.8230     13567
# weighted avg     0.9992    0.9991    0.9991     13567
#
# #######################################################################################
# WINDOW = 9, KNOWN_CUES = TRUE
#               precision    recall  f1-score   support
#
#            0     0.9982    0.9994    0.9988     13388
#            1     0.9503    0.8693    0.9080       176
#            2     1.0000    0.6667    0.8000         3
#
#     accuracy                         0.9976     13567
#    macro avg     0.9828    0.8451    0.9023     13567
# weighted avg     0.9976    0.9976    0.9976     13567
#
# #######################################################################################
# WINDOW = 9, KNOWN_CUES = FALSE
#               precision    recall  f1-score   support
#
#            0     0.9972    0.9990    0.9981     13388
#            1     0.9145    0.7898    0.8476       176
#            2     1.0000    0.6667    0.8000         3
#
#     accuracy                         0.9962     13567
#    macro avg     0.9705    0.8185    0.8819     13567
# weighted avg     0.9961    0.9962    0.9961     13567
#
# #######################################################################################
# WINDOW = 8, KNOWN_CUES = TRUE
#               precision    recall  f1-score   support
#
#            0     0.9983    0.9990    0.9987     13388
#            1     0.9222    0.8750    0.8980       176
#            2     1.0000    0.6667    0.8000         3
#
#     accuracy                         0.9973     13567
#    macro avg     0.9735    0.8469    0.8989     13567
# weighted avg     0.9973    0.9973    0.9973     13567
#
# #######################################################################################
# WINDOW = 8, KNOWN_CUES = FALSE
#               precision    recall  f1-score   support
#
#            0     0.9970    0.9994    0.9982     13388
#            1     0.9448    0.7784    0.8536       176
#            2     1.0000    0.6667    0.8000         3
#
#     accuracy                         0.9965     13567
#    macro avg     0.9806    0.8148    0.8839     13567
# weighted avg     0.9963    0.9965    0.9963     13567
#
# #######################################################################################
# WINDOW = 7, KNOWN_CUES = TRUE
#               precision    recall  f1-score   support
#
#            0     0.9982    0.9995    0.9988     13388
#            1     0.9563    0.8693    0.9107       176
#            2     1.0000    0.6667    0.8000         3
#
#     accuracy                         0.9977     13567
#    macro avg     0.9848    0.8452    0.9032     13567
# weighted avg     0.9977    0.9977    0.9977     13567
#
# #######################################################################################
# WINDOW = 7, KNOWN_CUES = FALSE
#               precision    recall  f1-score   support
#
#            0     0.9970    0.9995    0.9982     13388
#            1     0.9514    0.7784    0.8563       176
#            2     1.0000    0.6667    0.8000         3
#
#     accuracy                         0.9965     13567
#    macro avg     0.9828    0.8149    0.8848     13567
# weighted avg     0.9964    0.9965    0.9964     13567
#
# #######################################################################################
# WINDOW = 6, KNOWN_CUES = TRUE
#               precision    recall  f1-score   support
#
#            0     0.9982    0.9993    0.9987     13388
#            1     0.9387    0.8693    0.9027       176
#            2     1.0000    0.6667    0.8000         3
#
#     accuracy                         0.9975     13567
#    macro avg     0.9790    0.8451    0.9005     13567
# weighted avg     0.9974    0.9975    0.9974     13567
#
# #######################################################################################
# WINDOW = 6, KNOWN_CUES = FALSE
#               precision    recall  f1-score   support
#
#            0     0.9969    0.9993    0.9981     13388
#            1     0.9315    0.7727    0.8447       176
#            2     1.0000    0.6667    0.8000         3
#
#     accuracy                         0.9962     13567
#    macro avg     0.9762    0.8129    0.8809     13567
# weighted avg     0.9961    0.9962    0.9961     13567
#
# #######################################################################################
# WINDOW = 5, KNOWN_CUES = TRUE
#               precision    recall  f1-score   support
#
#            0     0.9982    0.9992    0.9987     13388
#            1     0.9329    0.8693    0.9000       176
#            2     1.0000    0.6667    0.8000         3
#
#     accuracy                         0.9974     13567
#    macro avg     0.9770    0.8451    0.8996     13567
# weighted avg     0.9974    0.9974    0.9974     13567
#
# #######################################################################################
# WINDOW = 5, KNOWN_CUES = FALSE
#               precision    recall  f1-score   support
#
#            0     0.9974    0.9990    0.9982     13388
#            1     0.9161    0.8068    0.8580       176
#            2     1.0000    0.6667    0.8000         3
#
#     accuracy                         0.9965     13567
#    macro avg     0.9712    0.8242    0.8854     13567
# weighted avg     0.9963    0.9965    0.9963     13567
#
# #######################################################################################
# WINDOW = 4, KNOWN_CUES = TRUE
#               precision    recall  f1-score   support
#
#            0     0.9982    0.9993    0.9987     13388
#            1     0.9387    0.8693    0.9027       176
#            2     1.0000    0.6667    0.8000         3
#
#     accuracy                         0.9975     13567
#    macro avg     0.9790    0.8451    0.9005     13567
# weighted avg     0.9974    0.9975    0.9974     13567
#
# #######################################################################################
# WINDOW = 4, KNOWN_CUES = FALSE
#               precision    recall  f1-score   support
#
#            0     0.9975    0.9990    0.9982     13388
#            1     0.9108    0.8125    0.8589       176
#            2     1.0000    0.6667    0.8000         3
#
#     accuracy                         0.9965     13567
#    macro avg     0.9694    0.8260    0.8857     13567
# weighted avg     0.9963    0.9965    0.9964     13567
#
# #######################################################################################
# WINDOW = 3, KNOWN_CUES = TRUE
#               precision    recall  f1-score   support
#
#            0     0.9982    0.9994    0.9988     13388
#            1     0.9503    0.8693    0.9080       176
#            2     1.0000    0.6667    0.8000         3
#
#     accuracy                         0.9976     13567
#    macro avg     0.9828    0.8451    0.9023     13567
# weighted avg     0.9976    0.9976    0.9976     13567
#
# #######################################################################################
# WINDOW = 3, KNOWN_CUES = FALSE
#               precision    recall  f1-score   support
#
#            0     0.9972    0.9995    0.9983     13388
#            1     0.9521    0.7898    0.8634       176
#            2     1.0000    0.6667    0.8000         3
#
#     accuracy                         0.9967     13567
#    macro avg     0.9831    0.8186    0.8872     13567
# weighted avg     0.9966    0.9967    0.9965     13567
#
# #######################################################################################
# WINDOW = 2, KNOWN_CUES = TRUE
#               precision    recall  f1-score   support
#
#            0     0.9982    0.9993    0.9987     13388
#            1     0.9387    0.8693    0.9027       176
#            2     1.0000    0.6667    0.8000         3
#
#     accuracy                         0.9975     13567
#    macro avg     0.9790    0.8451    0.9005     13567
# weighted avg     0.9974    0.9975    0.9974     13567
#
# #######################################################################################
# WINDOW = 2, KNOWN_CUES = FALSE
#               precision    recall  f1-score   support
#
#            0     0.9972    0.9994    0.9983     13388
#            1     0.9459    0.7955    0.8642       176
#            2     1.0000    0.6667    0.8000         3
#
#     accuracy                         0.9967     13567
#    macro avg     0.9811    0.8205    0.8875     13567
# weighted avg     0.9966    0.9967    0.9965     13567
#
# #######################################################################################
# WINDOW = 1, KNOWN_CUES = TRUE
#               precision    recall  f1-score   support
#
#            0     0.9981    0.9993    0.9987     13388
#            1     0.9383    0.8636    0.8994       176
#            2     1.0000    0.6667    0.8000         3
#
#     accuracy                         0.9974     13567
#    macro avg     0.9788    0.8432    0.8994     13567
# weighted avg     0.9974    0.9974    0.9974     13567
#
# #######################################################################################
# WINDOW = 1, KNOWN_CUES = FALSE
#               precision    recall  f1-score   support
#
#            0     0.9974    0.9996    0.9985     13388
#            1     0.9595    0.8068    0.8765       176
#            2     1.0000    0.6667    0.8000         3
#
#     accuracy                         0.9970     13567
#    macro avg     0.9856    0.8243    0.8917     13567
# weighted avg     0.9969    0.9970    0.9968     13567
#
# #######################################################################################
# WINDOW = 0, KNOWN_CUES = TRUE
#               precision    recall  f1-score   support
#
#            0     0.9982    0.9987    0.9985     13388
#            1     0.8947    0.8693    0.8818       176
#            2     1.0000    0.3333    0.5000         3
#
#     accuracy                         0.9969     13567
#    macro avg     0.9643    0.7338    0.7934     13567
# weighted avg     0.9969    0.9969    0.9968     13567
#
# #######################################################################################
# WINDOW = 0, KNOWN_CUES = FALSE
#               precision    recall  f1-score   support
#
#            0     0.9981    0.9990    0.9985     13388
#            1     0.9152    0.8580    0.8856       176
#            2     1.0000    0.3333    0.5000         3
#
#     accuracy                         0.9971     13567
#    macro avg     0.9711    0.7301    0.7947     13567
# weighted avg     0.9970    0.9971    0.9970     13567

# %% [markdown]
# # Hyper parameter optimization

# %% [markdown]
# ## Finding the best parameters

# %%
# define fixed parameters and parameters to search
crf = sklearn_crfsuite.CRF(
    algorithm='lbfgs',
    max_iterations=100,
    all_possible_transitions=True
)
params_space = {
    'c1': scipy.stats.expon(scale=0.5),
    'c2': scipy.stats.expon(scale=0.5),
}

labels = [0,1,2]
# use the same metric for evaluation
# use the same metric for evaluation
f1_scorer = make_scorer(metrics.flat_f1_score,
                        average='macro', labels=labels)

# search
rs = RandomizedSearchCV(crf, params_space,
                        cv=3,
                        verbose=1,
                        n_jobs=-1,
                        n_iter=100,
                        scoring=f1_scorer)


X_train_w7_kc, y_train = dataframe2features(train_df,window=7)
rs.fit(X_train_w7_kc, y_train)


print('best params:', rs.best_params_)
# Out:
# C:\Users\Martin\AppData\Roaming\Python\Python38\site-packages\sklearn\base.py:209: FutureWarning: From version 0.24, get_params will raise an AttributeError if a parameter cannot be retrieved as an instance attribute. Previously it would return None.
#   warnings.warn('From version 0.24, get_params will raise an '
# Fitting 3 folds for each of 50 candidates, totalling 150 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  34 tasks      | elapsed:  1.5min
# [Parallel(n_jobs=-1)]: Done 150 out of 150 | elapsed:  5.9min finished
# best params: {'c1': 0.9889626742960147, 'c2': 0.11115969864846051}

# %% [markdown]
# ### Comparing with the non-optimized training

# %%
X_train_w7_kc, y_train = dataframe2features(train_df,window=7)
X_test_w7_kc,  y_test  = dataframe2features(test_df,window=7)

print("#######################################################################################")
print("EVALUATION ON DEVELOPMENT HYPER PARAMS = TRUE")
crf_w7_kc, report_w7_kc = train_crf_and_predict(X_train_w7_kc,y_train,X_test_w7_kc,test_df['negCue'],c1=0.1073,c2=0.0144)
print("#######################################################################################")
print("EVALUATION ON DEVELOPMENT HYPER PARAMS = FALSE")

crf_w7_kc, report_w7_kc = train_crf_and_predict(X_train_w7_kc,y_train,X_test_w7_kc,test_df['negCue'])
# Out:
# #######################################################################################
# EVALUATION ON DEVELOPMENT HYPER PARAMS = TRUE
#               precision    recall  f1-score   support
#
#            0     0.9983    0.9993    0.9988     13388
#            1     0.9448    0.8750    0.9086       176
#            2     1.0000    0.6667    0.8000         3
#
#     accuracy                         0.9976     13567
#    macro avg     0.9810    0.8470    0.9025     13567
# weighted avg     0.9976    0.9976    0.9976     13567
#
# #######################################################################################
# EVALUATION ON DEVELOPMENT HYPER PARAMS = FALSE
#               precision    recall  f1-score   support
#
#            0     0.9982    0.9995    0.9988     13388
#            1     0.9563    0.8693    0.9107       176
#            2     1.0000    0.6667    0.8000         3
#
#     accuracy                         0.9977     13567
#    macro avg     0.9848    0.8452    0.9032     13567
# weighted avg     0.9977    0.9977    0.9977     13567

# %% [markdown]
# # Error Analysis

# %% [markdown]
# ## Pre-process eval datasets

# %%
# eval_df_1 = build_dataframe("corpus/SEM-2012-SharedTask-CD-SCO-test-cardboard.txt")
# eval_df_2 = build_dataframe("corpus/SEM-2012-SharedTask-CD-SCO-test-circle.txt")

# known_cues = get_training_cues(train_df)

# eval_df_1 = feature_extraction(eval_df_1,known_cues)
# eval_df_2 = feature_extraction(eval_df_2,known_cues)

# eval_df_1.to_csv('corpus/eval_df1_preproc_w9.csv', sep='\t',index=False)
# eval_df_2.to_csv('corpus/eval_df2_preproc_w9.csv', sep='\t',index=False)

# %% [markdown]
# ## Read preprocessed eval datasets

# %%
eval_df_1 = pd.read_csv('corpus/eval_df1_preproc_w9.csv', sep='\t')
eval_df_2 = pd.read_csv('corpus/eval_df2_preproc_w9.csv', sep='\t')

eval_df_1
# Out:
#             file  sentence  position     token    lemma postag lemma_a1  \
# 0      cardboard         0         0        In       in     IN   choose
# 1      cardboard         0         1  choosing   choose    VBG        a
# 2      cardboard         0         2         a        a     DT      few
# 3      cardboard         0         3       few      few     JJ  typical
# 4      cardboard         0         4   typical  typical     JJ     case
# ...          ...       ...       ...       ...      ...    ...      ...
# 10179  cardboard       495        16    answer   answer     NN       as
# 10180  cardboard       495        17        as       as     RB     ever
# 10181  cardboard       495        18      ever     ever     RB        .
# 10182  cardboard       495        19         .        .      .       ''
# 10183  cardboard       495        20        ''       ''     ''      NaN
#
#       lemma_b1 pos_a1 pos_b1  ...    lemma_a8 lemma_b8 pos_a8 pos_b8  \
# 0          NaN    VBG    NaN  ...         the      NaN     DT    NaN
# 1           in     DT     IN  ...  remarkable      NaN     JJ    NaN
# 2       choose     JJ    VBG  ...      mental      NaN     JJ    NaN
# 3            a     JJ     DT  ...     quality      NaN    NNS    NaN
# 4          few    NNS     JJ  ...          of      NaN     IN    NaN
# ...        ...    ...    ...  ...         ...      ...    ...    ...
# 10179       an     RB     DT  ...         NaN    which    NaN    WDT
# 10180   answer     RB     NN  ...         NaN    human    NaN     JJ
# 10181       as      .     RB  ...         NaN   reason    NaN     NN
# 10182     ever     ''     RB  ...         NaN       be    NaN    VBZ
# 10183        .    NaN      .  ...         NaN       as    NaN     RB
#
#          lemma_a9 lemma_b9 pos_a9 pos_b9 known_cue negCue
# 0      remarkable      NaN     JJ    NaN     False      0
# 1          mental      NaN     JJ    NaN     False      0
# 2         quality      NaN    NNS    NaN     False      0
# 3              of      NaN     IN    NaN     False      0
# 4              my      NaN   PRP$    NaN     False      0
# ...           ...      ...    ...    ...       ...    ...
# 10179         NaN       to    NaN     TO     False      0
# 10180         NaN    which    NaN    WDT     False      0
# 10181         NaN    human    NaN     JJ     False      0
# 10182         NaN   reason    NaN     NN     False      0
# 10183         NaN       be    NaN    VBZ     False      0
#
# [10184 rows x 44 columns]

# %% [markdown]
# ## Train model WS-7 and make predictions on eval df

# %%
X_train_w7, y_train = dataframe2features(train_df,window=7)
X_dev1_w7,  y_dev1  = dataframe2features(eval_df_1,window=7)
X_dev2_w7,  y_dev2  = dataframe2features(eval_df_2,window=7)

model_eval1, _ = train_crf_and_predict(X_train_w7, y_train, X_dev1_w7, eval_df_1['negCue'],verbose=False)
model_eval2, _ = train_crf_and_predict(X_train_w7, y_train, X_dev2_w7, eval_df_2['negCue'],verbose=False)

y_pred1 = model_eval1.predict(X_dev1_w7)
y_pred1_ = []

for sentence_preds in y_pred1:
    y_pred1_.extend(sentence_preds)

eval_df_1['pred'] = y_pred1_
eval_df_1 = eval_df_1.astype({'negCue': str})

""" -------------------------------------------------"""

y_pred2 = model_eval2.predict(X_dev2_w7)
y_pred2_ = []

for sentence_preds in y_pred2:
    y_pred2_.extend(sentence_preds)

eval_df_2['pred'] = y_pred2_
eval_df_2 = eval_df_2.astype({'negCue': str})
# Out:
# len(y_test)=10184
# len(y_pred_)=10184
# C:\Users\Martin\AppData\Roaming\Python\Python38\site-packages\sklearn\metrics\_classification.py:1221: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# len(y_test)=9032
# len(y_pred_)=9032

# %% [markdown]
# ## ANALYSIS

# %% [markdown]
# ### FALSE NEGATIVES

# %%
""" ###############       EVAL 1        #####################  """
dv1_fn = eval_df_1.loc[ ( (eval_df_1['negCue'] == '1') & ((eval_df_1['pred']== '0') |(eval_df_1['pred']== '2')) ) | (eval_df_1['negCue'] == '2') & ((eval_df_1['pred']== '0') |(eval_df_1['pred']== '1') )]
get_sentences2(eval_df_1, dv1_fn)
dv1_fn
# Out:
# [token: unsolved]
# 	->He loved to lie in the very center of five millions of people , with his filaments stretching out and running through them , responsive to every little rumour or suspicion of unsolved crime .
#
# [token: incredulity]
# 	->On my remarking that I was constantly in the habit of doing the same thing you expressed incredulity . ''
#
# [token: far]
# 	->But I was still far from satisfied .
#
# [token: from]
# 	->But I was still far from satisfied .
#
# [token: injustice]
# 	->`` You do yourself an injustice .
#
# [token: unframed]
# 	->Your eyes flashed across to the unframed portrait of Henry Ward Beecher which stands upon the top of your books .
#
# [token: unacquainted]
# 	->The parcel was directed , then , by a man -- the printing is distinctly masculine -- of limited education and unacquainted with the town of Croydon .
#
# [token: discoloured]
# 	->The other is a man 's , sun-burned , discoloured , and also pierced for an earring .
#
# [token: undoubtedly]
# 	->This quarrel had put a stop to all communications for some months , so that if Browner had occasion to address a packet to Miss Sarah , he would undoubtedly have done so to her old address .
#
# [token: unsuccessful]
# 	->An unsuccessful lover might have killed Mr. and Mrs. Browner , and the male ear might have belonged to the husband .
#
# [token: ceaseless]
# 	->Day by day she grew queerer and more irritable , and we had ceaseless rows about nothing .
#
# [token: inseparable]
# 	->Sarah avoided me now , but she and Mary were just inseparable .
#
# [token: not]
# 	->`` Why not ? '' says she .
#
# [token: unthinkable]
# 	->It must tend to some end , or else our universe is ruled by chance , which is unthinkable .
#             file  sentence  position         token         lemma postag  \
# 347    cardboard        12        32      unsolved      unsolved     JJ
# 589    cardboard        23        17   incredulity   incredulity     NN
# 669    cardboard        27         4           far           far     RB
# 670    cardboard        27         5          from          from     IN
# 751    cardboard        31         5     injustice     injustice     NN
# 904    cardboard        41         6      unframed      unframed     JJ
# 2765   cardboard       138        21  unacquainted  unacquainted     JJ
# 3317   cardboard       167         9   discoloured     discolour    VBN
# 6238   cardboard       322        29   undoubtedly   undoubtedly     RB
# 6480   cardboard       331         1  unsuccessful  unsuccessful     JJ
# 8353   cardboard       413        13     ceaseless     ceaseless     NN
# 8377   cardboard       415        11   inseparable   inseparable     JJ
# 8833   cardboard       436         2           not           not     RB
# 10157  cardboard       493        18   unthinkable   unthinkable     JJ
#
#         lemma_a1 lemma_b1 pos_a1 pos_b1  ...    lemma_b8 pos_a8 pos_b8  \
# 347        crime       of     NN     IN  ...  responsive    NaN     JJ
# 589            .  express      .    VBD  ...       habit    NaN     NN
# 669         from    still     IN     RB  ...         NaN    NaN    NaN
# 670    satisfied      far     JJ     RB  ...         NaN    NaN    NaN
# 751            .       an      .     DT  ...         NaN    NaN    NaN
# 904     portrait      the     NN     DT  ...         NaN     IN    NaN
# 2765        with      and     IN     CC  ...          be    NaN    VBZ
# 3317           ,        ,      ,      ,  ...           a      .     DT
# 6238        have    would     VB     MD  ...           a      .     DT
# 6480       lover       an     NN     DT  ...         NaN    NNP    NaN
# 8353         row     have    NNS    VBD  ...     queerer    NaN     NN
# 8377           .     just      .     RB  ...         now    NaN     RB
# 8833           ?      why      .    WRB  ...         NaN    NaN    NaN
# 10157          .       be      .    VBZ  ...    universe    NaN     NN
#
#       lemma_a9  lemma_b9 pos_a9 pos_b9 known_cue negCue pred
# 347        NaN         ,    NaN      ,     False      1    0
# 589        NaN       the    NaN     DT     False      1    0
# 669        NaN       NaN    NaN    NaN     False      1    0
# 670        NaN       NaN    NaN    NaN     False      2    0
# 751        NaN       NaN    NaN    NaN     False      1    0
# 904        the       NaN     DT    NaN     False      1    0
# 2765       NaN  printing    NaN     NN     False      1    0
# 3317       NaN        be    NaN    VBZ     False      1    0
# 6238       NaN   address    NaN     VB     False      1    0
# 6480         ,       NaN      ,    NaN     False      1    0
# 8353       NaN      grow    NaN    VBD     False      1    0
# 8377       NaN         I    NaN    PRP     False      1    0
# 8833       NaN       NaN    NaN    NaN      True      1    0
# 10157      NaN       our    NaN   PRP$     False      1    0
#
# [14 rows x 45 columns]

# %%
eval_df_1.loc[(eval_df_1['sentence']== 27)]
# Out:
#           file  sentence  position      token      lemma postag   lemma_a1  \
# 665  cardboard        27         0        But        but     CC          I
# 666  cardboard        27         1          I          I    PRP         be
# 667  cardboard        27         2        was         be    VBD      still
# 668  cardboard        27         3      still      still     RB        far
# 669  cardboard        27         4        far        far     RB       from
# 670  cardboard        27         5       from       from     IN  satisfied
# 671  cardboard        27         6  satisfied  satisfied     JJ          .
# 672  cardboard        27         7          .          .      .        NaN
#
#       lemma_b1 pos_a1 pos_b1  ... lemma_b8 pos_a8 pos_b8 lemma_a9 lemma_b9  \
# 665        NaN    PRP    NaN  ...      NaN    NaN    NaN      NaN      NaN
# 666        but    VBD     CC  ...      NaN    NaN    NaN      NaN      NaN
# 667          I     RB    PRP  ...      NaN    NaN    NaN      NaN      NaN
# 668         be     RB    VBD  ...      NaN    NaN    NaN      NaN      NaN
# 669      still     IN     RB  ...      NaN    NaN    NaN      NaN      NaN
# 670        far     JJ     RB  ...      NaN    NaN    NaN      NaN      NaN
# 671       from      .     IN  ...      NaN    NaN    NaN      NaN      NaN
# 672  satisfied    NaN     JJ  ...      NaN    NaN    NaN      NaN      NaN
#
#     pos_a9 pos_b9 known_cue negCue pred
# 665    NaN    NaN     False      0    0
# 666    NaN    NaN     False      0    0
# 667    NaN    NaN     False      0    0
# 668    NaN    NaN     False      0    0
# 669    NaN    NaN     False      1    0
# 670    NaN    NaN     False      2    0
# 671    NaN    NaN     False      0    0
# 672    NaN    NaN     False      0    0
#
# [8 rows x 45 columns]

# %%
""" ###############       EVAL 2        #####################  """
dv2_fn = eval_df_2.loc[ ( (eval_df_2['negCue'] == '1') & ((eval_df_2['pred']== '0') |(eval_df_2['pred']== '2')) ) | (eval_df_2['negCue'] == '2') & ((eval_df_2['pred']== '0') |(eval_df_2['pred']== '1') )]
get_sentences2(eval_df_2, dv2_fn)
dv2_fn
# Out:
# [token: more]
# 	->` If not , I 'll have no more to do with you . '
#
# [token: absolutely]
# 	->Do you say nothing has come out of that room -- absolutely nothing ? ''
#
# [token: nothing]
# 	->Do you say nothing has come out of that room -- absolutely nothing ? ''
#
# [token: more]
# 	->`` I 'll have no more of it !
#
# [token: carpetless]
# 	->On the deal boards of the carpetless floor there was outlined a fresh track of blood .
#
# [token: unconventional]
# 	->She spoke in rapid and fluent but very unconventional English , which , for the sake of clearness , I will make grammatical .
#
# [token: dislike]
# 	->At first I thought that it was dislike .
#
# [token: dislike]
# 	->And then , gradually , I understood that it was more than dislike .
#
# [token: senseless]
# 	->He struck Gennaro senseless and fled from the house which he was never more to enter .
#
# [token: more]
# 	->He struck Gennaro senseless and fled from the house which he was never more to enter .
#           file  sentence  position           token           lemma postag  \
# 676   circle01        41         8            more            more    JJR
# 1452  circle01       104        11      absolutely      absolutely     RB
# 1453  circle01       104        12         nothing         nothing     NN
# 2634  circle01       196         5            more            more    JJR
# 5939  circle02        65         6      carpetless      carpetless     JJ
# 7135  circle02       136         8  unconventional  unconventional     JJ
# 7711  circle02       164         7         dislike         dislike     NN
# 7725  circle02       165        12         dislike         dislike     NN
# 8175  circle02       182         3       senseless       senseless     NN
# 8185  circle02       182        13            more            more    JJR
#
#      lemma_a1    lemma_b1 pos_a1 pos_b1  ... lemma_b8 pos_a8 pos_b8  \
# 676        to          no     TO     DT  ...        `    NaN     ``
# 1452  nothing          --     NN      :  ...  nothing    NaN     NN
# 1453        ?  absolutely      .     RB  ...     have    NaN    VBZ
# 2634       of          no     IN     DT  ...      NaN    NaN    NaN
# 5939    floor         the     NN     DT  ...      NaN     IN    NaN
# 7135  English        very    NNP     RB  ...      she     IN    PRP
# 7711        .          be      .    VBD  ...      NaN    NaN    NaN
# 7725        .        than      .     IN  ...        ,    NaN      ,
# 8175      and     Gennaro     CC    NNP  ...      NaN    VBD    NaN
# 8185       to       never     TO     RB  ...     flee    NaN    VBD
#
#        lemma_a9   lemma_b9 pos_a9 pos_b9 known_cue negCue pred
# 676         NaN        NaN    NaN    NaN     False      2    0
# 1452        NaN        say    NaN     VB     False      1    0
# 1453        NaN    nothing    NaN     NN      True      2    1
# 2634        NaN        NaN    NaN    NaN     False      2    0
# 5939      blood        NaN     NN    NaN     False      1    0
# 7135  clearness        NaN     NN    NaN     False      1    0
# 7711        NaN        NaN    NaN    NaN     False      1    0
# 7725        NaN  gradually    NaN     RB     False      1    0
# 8175      never        NaN     RB    NaN     False      1    0
# 8185        NaN        and    NaN     CC     False      2    0
#
# [10 rows x 45 columns]

# %% [markdown]
# ### FALSE POSITIVES

# %%
""" ###############       EVAL 1        #####################  """
dv1_fp = eval_df_1.loc[ ( (eval_df_1['negCue'] == '0') & ((eval_df_1['pred']== '1') |(eval_df_1['pred']== '2')) )]
get_sentences2(eval_df_1, dv1_fp)
dv1_fp
# Out:
# [token: unfortunately]
# 	->It is , however , unfortunately impossible entirely to separate the sensational from the criminal , and a chronicler is left in the dilemma that he must either sacrifice details which are essential to his statement and so give a false impression of the problem , or he must use matter which chance , and not choice , has provided him with .
#
# [token: by]
# 	->Our blinds were half-drawn , and Holmes lay curled upon the sofa , reading and re-reading a letter which he had received by the morning post .
#
# [token: nothing]
# 	->The box is a yellow , half-pound honeydew box , with nothing distinctive save two thumb marks at the left bottom corner .
#
# [token: nothing]
# 	->The last six months that she was here she would speak of nothing but his drinking and his ways .
#
# [token: without]
# 	->I 'm never without one or the other before me .
#
# [token: never]
# 	->But she would have forgiven me ; she would have stuck as close to me as a rope to a block if that woman had never darkened our door .
#
# [token: nothing]
# 	->Day by day she grew queerer and more irritable , and we had ceaseless rows about nothing .
#            file  sentence  position          token          lemma postag  \
# 52    cardboard         1         5  unfortunately  unfortunately     RB
# 218   cardboard         6        22             by            NaN    NaN
# 2789  cardboard       140        11        nothing        nothing     NN
# 4518  cardboard       233        12        nothing        nothing     NN
# 7476  cardboard       376         3        without        without     IN
# 7613  cardboard       382        25          never          never     RB
# 8356  cardboard       413        16        nothing        nothing     NN
#
#          lemma_a1 lemma_b1 pos_a1 pos_b1  ...   lemma_b8 pos_a8 pos_b8  \
# 52     impossible        ,     JJ      ,  ...        NaN     DT    NaN
# 218           NaN      NaN    NaN    NaN  ...        NaN    NaN    NaN
# 2789  distinctive     with     JJ     IN  ...          ,     JJ      ,
# 4518          but       of     CC     IN  ...       that    NaN     IN
# 7476          one    never     CD     RB  ...        NaN    NaN    NaN
# 7613       darken     have    VBN    VBD  ...       rope    NaN     NN
# 8356            .    about      .     IN  ...  irritable    NaN     JJ
#
#       lemma_a9 lemma_b9 pos_a9 pos_b9 known_cue negCue pred
# 52    criminal      NaN     NN    NaN      True      0    1
# 218        NaN      NaN    NaN    NaN      True      0    1
# 2789    bottom   yellow     JJ     JJ      True      0    1
# 4518       NaN    month    NaN    NNS      True      0    1
# 7476       NaN      NaN    NaN    NaN      True      0    1
# 7613       NaN        a    NaN     DT      True      0    1
# 8356       NaN     more    NaN    RBR      True      0    1
#
# [7 rows x 45 columns]

# %% [markdown]
# # PLAYGROUND

# %%
eval_df_1.loc[eval_df_1['negCue']=='2']
# Out:
#           file  sentence  position token lemma postag   lemma_a1 lemma_b1  \
# 670  cardboard        27         5  from  from     IN  satisfied      far
#
#     pos_a1 pos_b1  ... lemma_b8 pos_a8 pos_b8 lemma_a9 lemma_b9 pos_a9 pos_b9  \
# 670     JJ     RB  ...      NaN    NaN    NaN      NaN      NaN    NaN    NaN
#
#     known_cue negCue pred
# 670     False      2    0
#
# [1 rows x 45 columns]

# %%
eval_df_1.loc[eval_df_1['lemma']=='unfortunately']
# Out:
#          file  sentence  position          token          lemma postag  \
# 52  cardboard         1         5  unfortunately  unfortunately     RB
#
#       lemma_a1 lemma_b1 pos_a1 pos_b1  ... lemma_b8 pos_a8 pos_b8  lemma_a9  \
# 52  impossible        ,     JJ      ,  ...      NaN     DT    NaN  criminal
#
#    lemma_b9 pos_a9 pos_b9 known_cue negCue pred
# 52      NaN     NN    NaN      True      0    1
#
# [1 rows x 45 columns]

# %%
train_df.loc[train_df['lemma']=='unfortunately']
# Out:
#                  file  sentence  position          token          lemma  \
# 16982  baskervilles05        76         3  unfortunately  unfortunately
#
#       postag lemma_a1 lemma_b1 pos_a1 pos_b1  ... lemma_a8 lemma_b8 pos_a8  \
# 16982     RB        ,        ,      ,      ,  ...      you      NaN    PRP
#
#       pos_b8 lemma_a9 lemma_b9 pos_a9 pos_b9 known_cue negCue
# 16982    NaN        .      NaN      .    NaN      True      1
#
# [1 rows x 44 columns]

# %%
# train_df.loc[train_df['']==]

train_df.loc[(train_df['lemma']=='nothing') & (train_df['negCue']==1)]
# Out:
#                  file  sentence  position    token    lemma postag  \
# 771    baskervilles01        38         6  nothing  nothing     NN
# 4817   baskervilles02        70        18  nothing  nothing     NN
# 6433   baskervilles02       134        28  nothing  nothing     NN
# 7242   baskervilles03         6         4  nothing  nothing     NN
# 7706   baskervilles03        51         3  nothing  nothing     NN
# 9018   baskervilles03       130         6  nothing  nothing     NN
# 11006  baskervilles04        10         1  Nothing  nothing     NN
# 11334  baskervilles04        32         6  nothing  nothing     NN
# 12130  baskervilles04        72        16  nothing  nothing     NN
# 12864  baskervilles04       111         1  Nothing  nothing     NN
# 12993  baskervilles04       120         2  nothing  nothing     NN
# 17297  baskervilles05        99        36  nothing  nothing     NN
# 18492  baskervilles05       178         9  nothing  nothing     NN
# 18727  baskervilles05       191         2  nothing  nothing     NN
# 18891  baskervilles05       201         3  nothing  nothing     NN
# 19104  baskervilles05       212        20  nothing  nothing     NN
# 19761  baskervilles05       262         1  Nothing  nothing     NN
# 19774  baskervilles05       263         5  nothing  nothing     NN
# 20380  baskervilles06        17        25  nothing  nothing     NN
# 21980  baskervilles06        90         8  nothing  nothing     NN
# 27268  baskervilles07       179         0  Nothing  nothing     NN
# 29928  baskervilles07       335         2  nothing  nothing     NN
# 30469  baskervilles08        15        20  nothing  nothing     NN
# 30575  baskervilles08        20        16  nothing  nothing     NN
# 30631  baskervilles08        24         3  nothing  nothing     NN
# 34646  baskervilles09        68        43  nothing  nothing     NN
# 35918  baskervilles09       132        26  nothing  nothing     NN
# 37076  baskervilles09       176         1  Nothing  nothing     NN
# 37463  baskervilles09       200         9  nothing  nothing     NN
# 37465  baskervilles09       200        11  nothing  nothing     NN
# 37754  baskervilles09       223         3  nothing  nothing     NN
# 39052  baskervilles09       299         7  nothing  nothing     NN
# 39611  baskervilles09       344         2  nothing  nothing     NN
# 41254  baskervilles10        17        27  nothing  nothing     NN
# 41707  baskervilles10        41         3  nothing  nothing     NN
# 42032  baskervilles10        55        18  nothing  nothing     NN
# 42212  baskervilles10        66         8  nothing  nothing     NN
# 44940  baskervilles10       235        16  nothing  nothing     NN
# 45830  baskervilles11        24         3  nothing  nothing     NN
# 45847  baskervilles11        25         4  nothing  nothing     NN
# 48372  baskervilles11       175        14  nothing  nothing     NN
# 49290  baskervilles11       236         0  Nothing  nothing     NN
# 53344  baskervilles12       163        19  nothing  nothing     NN
# 53359  baskervilles12       165         1  Nothing  nothing     NN
# 54644  baskervilles12       243         3  nothing  nothing     NN
# 55255  baskervilles12       288         3  nothing  nothing     NN
# 55894  baskervilles13        15         3  nothing  nothing     NN
# 56280  baskervilles13        39         3  nothing  nothing     NN
# 56326  baskervilles13        43         1  nothing  nothing     NN
# 58966  baskervilles13       199         2  nothing  nothing     NN
# 59851  baskervilles13       259         9  nothing  nothing     NN
# 60074  baskervilles13       270         4  nothing  nothing     NN
# 60100  baskervilles13       272         8  nothing  nothing     NN
# 60736  baskervilles14         6        25  nothing  nothing     NN
# 64010  baskervilles14       203         4  nothing  nothing     NN
# 64012  baskervilles14       203         6  nothing  nothing     NN
#
#            lemma_a1 lemma_b1 pos_a1 pos_b1  ...   lemma_a8 lemma_b8 pos_a8  \
# 771              of       be     IN    VBZ  ...         ''      NaN     ''
# 4817        thereof      say     RB    VBP  ...         ''      and     ''
# 6433          would        ,     MD      ,  ...        the       he     DT
# 7242              ?      say      .    VBD  ...        NaN      NaN    NaN
# 7706              ?     find      .    VBD  ...        NaN      NaN    NaN
# 9018             to      say     IN     VB  ...       make      NaN    VBN
# 11006            of        `     IN     ``  ...        NaN      NaN    NaN
# 11334  supernatural       be     JJ    VBZ  ...          ?      NaN      .
# 12130          else     from     RB     IN  ...        NaN      and    NaN
# 12864             ,        `      ,     ``  ...       down      NaN     RP
# 12993          else     have     RB    VBP  ...         go      NaN    VBP
# 17297            to      and     TO     CC  ...        NaN    these    NaN
# 18492            of     know     IN     VB  ...    inquiry   German     NN
# 18727          more       be    RBR    VBZ  ...         go      NaN    VBZ
# 18891            in     have     IN    VBP  ...       good      NaN     JJ
# 19104         about      say     IN     VB  ...        NaN        a    NaN
# 19761          more        `    JJR     ``  ...        NaN      NaN    NaN
# 19774             .        ;      .      :  ...        NaN      NaN    NaN
# 20380             .     know      .    VBP  ...        NaN       be    NaN
# 21980             .       at      .     IN  ...        NaN     this    NaN
# 27268          stir      NaN    VBD    NaN  ...       pair      NaN     NN
# 29928            to       be     TO    VBZ  ...          ,      NaN      ,
# 30469            of       be     IN    VBD  ...        NaN       it    NaN
# 30575          have      and    VBZ     CC  ...        NaN   during    NaN
# 30631            to       be     TO    VBZ  ...        and      NaN     CC
# 34646          more       be    JJR    VBD  ...        NaN       be    NaN
# 35918       against     know     IN    VBP  ...       fate      all     NN
# 37076             ,        `      ,     ``  ...        NaN      NaN    NaN
# 37463            --       be      :    VBZ  ...     butler       no     NN
# 37465            --       be      :    VBZ  ...     butler       no     NN
# 37754        except       do     IN    VBN  ...        ask      NaN    VBD
# 39052          come      but    VBD     CC  ...        NaN      NaN    NaN
# 39611            so       be     RB    VBZ  ...      light      NaN     NN
# 41254          will      and     MD     CC  ...          a     upon     DT
# 41707            to      say     TO     VB  ...          I      NaN    PRP
# 42032             .       at      .     IN  ...        NaN       he    NaN
# 42212            to      say     IN     VB  ...        NaN        I    NaN
# 44940          away     give     RB    VBZ  ...        NaN      but    NaN
# 45830            in       be     IN    VBZ  ...          ,      NaN      ,
# 45847             ,       he      ,    PRP  ...          .      NaN      .
# 48372         would      but     MD     CC  ...         in     what     IN
# 49290         would      NaN     MD    NaN  ...         in      NaN     IN
# 53344          move      and    VBD     CC  ...        NaN   shadow    NaN
# 53359             .        `      .     ``  ...        NaN      NaN    NaN
# 54644             .  presume      .    VBP  ...        NaN      NaN    NaN
# 55255            of     hear     IN    VBD  ...          .      NaN      .
# 55894       against    prove     IN     VB  ...        NaN      NaN    NaN
# 56280           far     draw     RB     VB  ...          ,      NaN      ,
# 56326            of      say     IN     VB  ...        NaN      NaN    NaN
# 58966           for       be     IN    VBD  ...  obedience      NaN     NN
# 59851         which       be    WDT    VBZ  ...        NaN        I    NaN
# 60074         until     hear     IN    VBD  ...      death      NaN     NN
# 60100         about      say     IN     VB  ...         ''        `     ''
# 60736             ,      say      ,    VBN  ...        his    final   PRP$
# 64010            --       be      :    VBZ  ...        NaN      NaN    NaN
# 64012            --       be      :    VBZ  ...        NaN      NaN    NaN
#
#       pos_b8   lemma_a9  lemma_b9 pos_a9 pos_b9 known_cue negCue
# 771      NaN        NaN       NaN    NaN    NaN      True      1
# 4817      CC        NaN    Rodger    NaN    NNP      True      1
# 6433     PRP       moor  although     NN     IN      True      1
# 7242     NaN        NaN       NaN    NaN    NaN      True      1
# 7706     NaN        NaN       NaN    NaN    NaN      True      1
# 9018     NaN         up       NaN     RP    NaN      True      1
# 11006    NaN        NaN       NaN    NaN    NaN      True      1
# 11334    NaN         ''       NaN     ''    NaN      True      1
# 12130     CC        NaN         ,    NaN      ,      True      1
# 12864    NaN          .       NaN      .    NaN      True      1
# 12993    NaN       into       NaN     IN    NaN      True      1
# 17297     DT        NaN      Hall    NaN    NNP      True      1
# 18492    NNP      clear       the     VB     DT      True      1
# 18727    NaN    against       NaN     IN    NaN      True      1
# 18891    NaN        man       NaN     NN    NaN      True      1
# 19104     DT        NaN        be    NaN    VBD      True      1
# 19761    NaN        NaN       NaN    NaN    NaN      True      1
# 19774    NaN        NaN       NaN    NaN    NaN      True      1
# 20380    VBZ        NaN     there    NaN     EX      True      1
# 21980     DT        NaN       NaN    NaN    NaN      True      1
# 27268    NaN         of       NaN     IN    NaN      True      1
# 29928    NaN      could       NaN     MD    NaN      True      1
# 30469    PRP        NaN       day    NaN    NNS      True      1
# 30575     IN        NaN         ,    NaN      ,      True      1
# 30631    NaN  slaughter       NaN     VB    NaN      True      1
# 34646    VBD        NaN  position    NaN     NN      True      1
# 35918     RB      which        be    WDT    VBP      True      1
# 37076    NaN        NaN       NaN    NaN    NaN      True      1
# 37463     UH      break         `    VBD     ``      True      1
# 37465     UH      break         `    VBD     ``      True      1
# 37754    NaN         he       NaN    PRP    NaN      True      1
# 39052    NaN        NaN       NaN    NaN    NaN      True      1
# 39611    NaN       upon       NaN     IN    NaN      True      1
# 41254     IN      thing   quality     NN     NN      True      1
# 41707    NaN       will       NaN     MD    NaN      True      1
# 42032    PRP        NaN       and    NaN     CC      True      1
# 42212    PRP        NaN       NaN    NaN    NaN      True      1
# 44940     CC        NaN         ,    NaN      ,      True      1
# 45830    NaN         ''       NaN     ''    NaN      True      1
# 45847    NaN        NaN       NaN    NaN    NaN      True      1
# 48372     WP        any      they     DT    PRP      True      1
# 49290    NaN        any       NaN     DT    NaN      True      1
# 53344    NNS        NaN       the    NaN     DT      True      1
# 53359    NaN        NaN       NaN    NaN    NaN      True      1
# 54644    NaN        NaN       NaN    NaN    NaN      True      1
# 55255    NaN        NaN       NaN    NaN    NaN      True      1
# 55894    NaN        NaN       NaN    NaN    NaN      True      1
# 56280    NaN       lose       NaN    VBN    NaN      True      1
# 56326    NaN        NaN       NaN    NaN    NaN      True      1
# 58966    NaN          ;       NaN      :    NaN      True      1
# 59851    PRP        NaN       ask    NaN     VB      True      1
# 60074    NaN         in       NaN     IN    NaN      True      1
# 60100     ``        NaN         `    NaN     ``      True      1
# 60736     JJ     course       our     NN   PRP$      True      1
# 64010    NaN        NaN       NaN    NaN    NaN      True      1
# 64012    NaN        NaN       NaN    NaN    NaN      True      1
#
# [56 rows x 44 columns]

# %%
nothing_bneg = train_df.loc[(train_df['lemma']=='nothing') & (train_df['negCue']==1)]
# get_sentences2(train_df, nothing_bneg)

# %%
nothing_O = train_df.loc[(train_df['lemma']=='nothing') & (train_df['negCue']==0)]
get_sentences2(train_df, nothing_O)
nothing_O
# Out:
# [token: nothing]
# 	->He would talk of nothing but art , of which he had the crudest ideas , from our leaving the gallery until we found ourselves at the Northumberland Hotel .
#
# [token: nothing]
# 	->I am certainly developing the wisdom of the serpent , for when Mortimer pressed his questions to an inconvenient extent I asked him casually to what type Frankland 's skull belonged , and so heard nothing but craniology for the rest of our drive .
#
# [token: nothing]
# 	->I have not lived for years with Sherlock Holmes for nothing .
#
# [token: nothing]
# 	->I hope to heaven that he has gone , for he has brought nothing but trouble here !
#                  file  sentence  position    token    lemma postag lemma_a1  \
# 15798  baskervilles05         3         4  nothing  nothing     NN      but
# 44265  baskervilles10       190        35  nothing  nothing     NN      but
# 44285  baskervilles10       191        10  nothing  nothing     NN        .
# 44409  baskervilles10       198        13  nothing  nothing     NN      but
#
#       lemma_b1 pos_a1 pos_b1  ... lemma_a8   lemma_b8 pos_a8 pos_b8 lemma_a9  \
# 15798       of     IN     IN  ...      the        NaN     DT    NaN    crude
# 44265     hear     IN    VBD  ...    drive  Frankland     NN    NNP        .
# 44285      for      .     IN  ...      NaN        not    NaN     RB      NaN
# 44409    bring     IN    VBN  ...      NaN         he    NaN    PRP      NaN
#
#       lemma_b9 pos_a9 pos_b9 known_cue negCue
# 15798      NaN    JJS    NaN      True      0
# 44265     type      .     NN      True      0
# 44285     have    NaN    VBP      True      0
# 44409     that    NaN     IN      True      0
#
# [4 rows x 44 columns]

# %%
train_df.loc[(train_df['negCue']== 2)]
# Out:
#                  file  sentence  position     token     lemma postag  \
# 883    baskervilles01        47        13        no        no     DT
# 884    baskervilles01        47        14     means     means     NN
# 4393   baskervilles02        59         6        no        no     DT
# 4394   baskervilles02        59         7     means      mean    NNS
# 9751   baskervilles03       182         2       the       the     DT
# 9752   baskervilles03       182         3  contrary  contrary     NN
# 10576  baskervilles03       236        24      than      than     IN
# 10682  baskervilles03       243         1       the       the     DT
# 10683  baskervilles03       243         2  contrary  contrary     NN
# 14288  baskervilles04       197         2       for       for     IN
# 14289  baskervilles04       197         3       the       the     DT
# 14290  baskervilles04       197         4     world     world     NN
# 20280  baskervilles06        11         2        no        no     DT
# 20281  baskervilles06        11         3     means      mean    NNS
# 37466  baskervilles09       200        12        at        at     RB
# 37467  baskervilles09       200        13       all       all     RB
#
#        lemma_a1 lemma_b1 pos_a1 pos_b1  ... lemma_a8 lemma_b8 pos_a8 pos_b8  \
# 883       means       by     NN     IN  ...      NaN       my    NaN   PRP$
# 884         all       no     DT     DT  ...      NaN     dear    NaN     JJ
# 4393       mean       by    NNS     IN  ...        ,      NaN      ,    NaN
# 4394    advance       no     NN     DT  ...      the      NaN     DT    NaN
# 9751   contrary       on     NN     IN  ...        .      NaN      .    NaN
# 9752          ,      the      ,     DT  ...       ''      NaN     ''    NaN
# 10576        in   rather     IN     RB  ...      NaN     wait    NaN    VBG
# 10682  contrary       on     NN     IN  ...    avoid      NaN    VBD    NaN
# 10683         ,      the      ,     DT  ...      the      NaN     DT    NaN
# 14288       the      not     DT     RB  ...      NaN      NaN    NaN    NaN
# 14289     world      for     NN     IN  ...      NaN      NaN    NaN    NaN
# 14290         ,      the      ,     DT  ...      NaN      NaN    NaN    NaN
# 20280      mean       by    NNS     IN  ...      NaN      NaN    NaN    NaN
# 20281         .       no      .     DT  ...      NaN      NaN    NaN    NaN
# 37466       all  nothing     RB     NN  ...        ;        ,      :      ,
# 37467         !       at      .     RB  ...        `      sir     ``     NN
#
#       lemma_a9 lemma_b9 pos_a9 pos_b9 known_cue negCue
# 883        NaN        ,    NaN      ,      True      2
# 884        NaN       my    NaN   PRP$     False      2
# 4393       the      NaN     DT    NaN      True      2
# 4394      bold      NaN    JJS    NaN     False      2
# 9751        ''      NaN     ''    NaN     False      2
# 9752       NaN      NaN    NaN    NaN     False      2
# 10576      NaN       he    NaN    PRP     False      2
# 10682      the      NaN     DT    NaN     False      2
# 10683     moor      NaN     NN    NaN     False      2
# 14288      NaN      NaN    NaN    NaN     False      2
# 14289      NaN      NaN    NaN    NaN     False      2
# 14290      NaN      NaN    NaN    NaN     False      2
# 20280      NaN      NaN    NaN    NaN      True      2
# 20281      NaN      NaN    NaN    NaN     False      2
# 37466        `       no     ``     UH     False      2
# 37467        `        ,     ``      ,     False      2
#
# [16 rows x 44 columns]
